# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("birth-rates-yearly.csv")
df
# Out:
#       year    rate
# 0     1960  36.400
# 1     1961  35.179
# 2     1962  33.863
# 3     1963  32.459
# 4     1964  30.994
# ...    ...     ...
# 9865  2004  30.123
# 9866  2005  30.067
# 9867  2006  30.027
# 9868  2007  29.987
# 9869  2008  29.930
#
# [9870 rows x 2 columns]

# %%
avg = df.groupby('year')[['rate']].mean().reset_index()
avg
# Out:
#     year       rate
# 0   1960  38.143298
# 1   1961  39.309189
# 2   1962  38.139809
# 3   1963  38.983646
# 4   1964  38.636152
# 5   1965  36.927179
# 6   1966  37.605933
# 7   1967  36.212692
# 8   1968  36.880024
# 9   1969  36.501018
# 10  1970  34.828550
# 11  1971  35.851927
# 12  1972  34.412160
# 13  1973  35.090506
# 14  1974  34.718621
# 15  1975  33.149989
# 16  1976  33.832035
# 17  1977  32.632433
# 18  1978  33.209006
# 19  1979  32.968371
# 20  1980  31.671848
# 21  1981  32.008343
# 22  1982  31.340386
# 23  1983  31.559597
# 24  1984  31.313783
# 25  1985  30.332996
# 26  1986  30.669408
# 27  1987  29.801436
# 28  1988  29.589116
# 29  1989  29.018110
# 30  1990  28.397586
# 31  1991  27.972156
# 32  1992  27.289441
# 33  1993  26.961650
# 34  1994  26.417772
# 35  1995  25.679301
# 36  1996  25.302754
# 37  1997  24.793530
# 38  1998  24.327411
# 39  1999  24.606884
# 40  2000  23.630850
# 41  2001  23.215782
# 42  2002  22.885726
# 43  2003  22.731459
# ...

# %%
plt.figure(figsize=(12, 6))
plt.scatter(avg['year'], avg['rate'])           # scatter plot showing actual data
plt.xlabel('Year')
plt.ylabel('Birth Rate')
plt.title('Yearly Birth Rate')
plt.show()

# %%
df1=pd.read_csv('crimerates-by-state-2005.csv')
df1=df1.drop([0,9])
df1
# Out:
#              state  murder  forcible_rape  robbery  aggravated_assault  \
# 1          Alabama     8.2           34.3    141.4               247.8
# 2           Alaska     4.8           81.1     80.9               465.1
# 3          Arizona     7.5           33.8    144.4               327.4
# 4         Arkansas     6.7           42.9     91.1               386.8
# 5       California     6.9           26.0    176.1               317.3
# 6         Colorado     3.7           43.4     84.6               264.7
# 7      Connecticut     2.9           20.0    113.0               138.6
# 8         Delaware     4.4           44.7    154.8               428.2
# 10         Florida     5.0           37.1    169.4               496.6
# 11         Georgia     6.2           23.6    154.8               264.3
# 12          Hawaii     1.9           26.9     78.5               147.8
# 13           Idaho     2.4           40.4     18.6               195.4
# ...

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df1['population'], df1['murder'], df1['robbery'], alpha=0.5)           # scatter plot showing actual data
plt.xlabel('Population')
plt.ylabel('Murder Rate')
plt.title('Murder rate per population with robbery rates as bubble size')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.displot(avg, x="year", kind="kde")
plt.xlabel('Year')
plt.ylabel('Birth Rate')
plt.title('Yearly Birth Rate')
plt.show()
